# %%
# !pwd
# Out:
# /home/khordadi/simd

# %%
import pandas as pd

df = pd.read_csv('result.csv')
df = df.pivot(index='Operation', columns='Mode', values='Bandwidth(GB/s)')
df = df[['Same', 'Linear', 'Random']]
df.reset_index(inplace=True)
df
# Out:
# Mode Operation    Same  Linear  Random
# 0         LD1D  111.98   54.34   15.56
# 1         LD2D   94.27   54.31   15.55
# 2         ST1D   31.85   52.84   51.49
# 3         ST2D   31.86   52.39   51.51
